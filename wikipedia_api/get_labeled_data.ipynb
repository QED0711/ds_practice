# %%
# %load_ext autoreload
# %autoreload 1

import pandas as pd

pd.options.display.max_rows = 999

import requests
import time
import signal

from WikiScrapper import WikiScrapper
from get_related_links import *

# %aimport WikiScrapper
# %aimport get_related_links

# %%
titles_df = pd.read_csv("top_wikipedia_articles.csv")

# %%
# for i in range(titles_df.shape[0]):
#     current = titles_df.iloc[i]
    
#     if current.visited == 0:
        
#         title = current.title
        
#         scrapper = WikiScrapper.WikiScrapper()
#         try:
#             scrapper.traverse_from("https://en.wikipedia.org/wiki/{}".format(title), max_depth=3, max_nodes=None)
#             scrapper.to_mlab()
#         except:
#             print(title, "skipped")
            
#         titles_df.iloc[i,1] = 1
#         titles_df.to_csv("top_wikipedia_articles.csv", index=False)
        
# #         print(title)
    
#         time.sleep(2)

# %%
get_related_links.get_related_links("https://en.wikipedia.org/wiki/Germany")

# %%
scrapper = WikiScrapper.WikiScrapper()
scrapper.traverse_from("https://en.wikipedia.org/wiki/List_of_diagnostic_classification_and_rating_scales_used_in_psychiatry", max_depth=3, max_nodes=None);

# %%
scrapper.data

# %%
for i in range(10):
    print(i, end="\r", flush=True)
    time.sleep(1)

# %%
labeled_df = pd.read_csv("labeled_data.csv")

labeled_df.head(50)
# Out:
#                              title  \
# 0                       Zeroth law
# 1                     Zeroth-order
# 2         Division by Zero (story)
# 3               Indeterminate form
# 4                     Zero divisor
# 5                       Count noun
# 6          Grammatical conjugation
# 7                       Inflection
# 8                     Measure word
# 9                 English numerals
# 10      Foundations of mathematics
# 11                               0
# 12                             0th
# 13                     Brahmagupta
# 14                Division by zero
# 15              Grammatical number
# 16                   Number theory
# 17                    Peano axioms
# 18                     Signed zero
# 19  Brahmagupta–Fibonacci identity
# 20             Brahmagupta theorem
# 21                       Asymptote
# 22                    Well-defined
# 23                          Elohim
# 24              Generic antecedent
# 25         Agreement (linguistics)
# 26              Grammatical person
# 27                      Noun class
# 28                  Plurale tantum
# 29                 Romance plurals
# 30        Algebraic function field
# 31                    Finite field
# 32                   p-adic number
# 33             Goodstein's theorem
# 34        Paris–Harrington theorem
# 35           Presburger arithmetic
# 36             Robinson arithmetic
# 37         Second-order arithmetic
# 38       Extended real number line
# 39                     Abiogenesis
# 40             Anthropic principle
# 41                 Artificial cell
# 42                 Artificial life
# 43                  Astrochemistry
# 44          Biological immortality
# 45        Carbon Mineral Challenge
# 46                  Common descent
# 47                Entropy and life
# 48            Mediocrity principle
# 49                          Tholin
#
#                                                   url  \
# 0   https://en.wikipedia.org/wiki/Zeroth_law_(disa...
# 1   https://en.wikipedia.org/wiki/Zeroth-order_(di...
# 2   https://en.wikipedia.org/wiki/Division_by_Zero...
# 3    https://en.wikipedia.org/wiki/Indeterminate_form
# 4          https://en.wikipedia.org/wiki/Zero_divisor
# 5            https://en.wikipedia.org/wiki/Count_noun
# 5   ['https://en.wikipedia.org/wiki/Collective_nou...
# 6   ['https://en.wikipedia.org/wiki/Category:Gramm...
# 7   ['https://en.wikipedia.org/wiki/Agreement_(lin...
# 8   ['https://en.wikipedia.org/wiki/Collective_nou...
# 9   ['https://en.wikipedia.org/wiki/Indefinite_and...
# 10  ['https://en.wikipedia.org/wiki/Mathematical_l...
# 11  ['https://en.wikipedia.org/wiki/0th_(disambigu...
# 12  ['https://en.wikipedia.org/wiki/OTH_(disambigu...
# 13  ['https://en.wikipedia.org/wiki/Brahmagupta%E2...
# 14  ['https://en.wikipedia.org/wiki/Asymptote', 'h...
# 15  ['https://en.wikipedia.org/wiki/Count_noun', '...
# 16  ['https://en.wikipedia.org/wiki/Algebraic_func...
# 17  ['https://en.wikipedia.org/wiki/Foundations_of...
# 18  ['https://en.wikipedia.org/wiki/Line_with_two_...
# 19  ['https://en.wikipedia.org/wiki/Brahmagupta_ma...
# 20  ['https://en.wikipedia.org/wiki/Brahmagupta%27...
# 21   ['https://en.wikipedia.org/wiki/Big_O_notation']
# 22  ['https://en.wikipedia.org/wiki/Equivalence_re...
# 23  ['https://en.wikipedia.org/wiki/Allahumma', 'h...
# 24  ['https://en.wikipedia.org/wiki/Donkey_pronoun...
# 25  ['https://en.wikipedia.org/wiki/Attraction_(gr...
# 26  ['https://en.wikipedia.org/wiki/English_person...
# 27  ['https://en.wikipedia.org/wiki/Animacy', 'htt...
# 28  ['https://en.wikipedia.org/wiki/Classifier_(li...
# 29  ['https://en.wikipedia.org/wiki/Classification...
# 30  ['https://en.wikipedia.org/wiki/Function_field...
# 31  ['https://en.wikipedia.org/wiki/Quasi-finite_f...
# 32  ['https://en.wikipedia.org/wiki/1_%2B_2_%2B_4_...
# 33  ['https://en.wikipedia.org/wiki/Non-standard_m...
# 34  ['https://en.wikipedia.org/wiki/Goodstein%27s_...
# 35  ['https://en.wikipedia.org/wiki/Robinson_arith...
# 36  ['https://en.wikipedia.org/wiki/General_set_th...
# 37  ['https://en.wikipedia.org/wiki/Paris%E2%80%93...
# 38  ['https://en.wikipedia.org/wiki/Projectively_e...
# 39  ['https://en.wikipedia.org/wiki/Anthropic_prin...
# 40  ['https://en.wikipedia.org/wiki/Big_Bounce', '...
# 41  ['https://en.wikipedia.org/wiki/Chemoton', 'ht...
# 42  ['https://en.wikipedia.org/wiki/Artificial_con...
# 43  ['https://en.wikipedia.org/wiki/Astrobotany', ...
# 44  ['https://en.wikipedia.org/wiki/Aging_brain', ...
# 45  ['https://en.wikipedia.org/wiki/Abiogenesis', ...
# 46  ['https://en.wikipedia.org/wiki/The_Ancestor%2...
# 47  ['https://en.wikipedia.org/wiki/Abiogenesis', ...
# 48  ['https://en.wikipedia.org/wiki/Abiogenesis', ...
# 49  ['https://en.wikipedia.org/wiki/Abiogenesis', ...
